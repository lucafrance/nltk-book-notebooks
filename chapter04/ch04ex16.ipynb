# %% [markdown]
# Read up on Gematria, a method for assigning numbers to words, and for mapping between words having the same number to discover the hidden meaning of texts (http://en.wikipedia.org/wiki/Gematria, http://essenes.net/gemcal.htm).
#
# - a. Write a function `gematria()` that sums the numerical values of the letters of a word, according to the letter values in letter_vals:
#     ```python
#     >>> letter_vals = {'a':1, 'b':2, 'c':3, 'd':4, 'e':5, 'f':80, 'g':3, 'h':8,
#     ... 'i':10, 'j':10, 'k':20, 'l':30, 'm':40, 'n':50, 'o':70, 'p':80, 'q':100,
#     ... 'r':200, 's':300, 't':400, 'u':6, 'v':6, 'w':800, 'x':60, 'y':10, 'z':7}
#     ```
# - b. Process a corpus (e.g. `nltk.corpus.state_union`) and for each document, count how many of its words have the number 666.
# - c. Write a function `decode()` to process a text, randomly replacing words with their Gematria equivalents, in order to discover the "hidden meaning" of the text.

# %%
def gematria(word):
    letter_vals = {'a':1, 'b':2, 'c':3, 'd':4, 'e':5, 'f':80, 'g':3, 'h':8,
        'i':10, 'j':10, 'k':20, 'l':30, 'm':40, 'n':50, 'o':70, 'p':80, 'q':100,
        'r':200, 's':300, 't':400, 'u':6, 'v':6, 'w':800, 'x':60, 'y':10, 'z':7}
    try:
        n = sum(letter_vals[c] for c in word.lower())
    except Exception as e:
        n = 0
    return n

# %%
gematria("ciao")
# Out:
# 84

# %%
3+10+1+70
# Out:
# 84

# %%
gematria("1234")
# Out:
# 0

# %%
gematria(",")
# Out:
# 0

# %%
from nltk.corpus import state_union
for fileid in state_union.fileids():
    text = state_union.words(fileid)
    count_666 = len([w for w in text if gematria(w) == 666])
    print(fileid, ": ", count_666)
# Out:
# 1945-Truman.txt :  2
# 1946-Truman.txt :  13
# 1947-Truman.txt :  0
# 1948-Truman.txt :  2
# 1949-Truman.txt :  2
# 1950-Truman.txt :  1
# 1951-Truman.txt :  0
# 1953-Eisenhower.txt :  1
# 1954-Eisenhower.txt :  6
# 1955-Eisenhower.txt :  3
# 1956-Eisenhower.txt :  1
# 1957-Eisenhower.txt :  2
# 1958-Eisenhower.txt :  5
# 1959-Eisenhower.txt :  1
# 1960-Eisenhower.txt :  5
# 1961-Kennedy.txt :  0
# 1962-Kennedy.txt :  11
# 1963-Johnson.txt :  0
# 1963-Kennedy.txt :  5
# 1964-Johnson.txt :  1
# 1965-Johnson-1.txt :  0
# 1965-Johnson-2.txt :  0
# 1966-Johnson.txt :  0
# 1967-Johnson.txt :  2
# 1968-Johnson.txt :  3
# 1969-Johnson.txt :  0
# 1970-Nixon.txt :  0
# 1971-Nixon.txt :  1
# 1972-Nixon.txt :  0
# 1973-Nixon.txt :  1
# 1974-Nixon.txt :  0
# 1975-Ford.txt :  0
# 1976-Ford.txt :  3
# 1977-Ford.txt :  0
# 1978-Carter.txt :  1
# 1979-Carter.txt :  2
# 1980-Carter.txt :  0
# 1981-Reagan.txt :  4
# 1982-Reagan.txt :  0
# 1983-Reagan.txt :  2
# 1984-Reagan.txt :  1
# 1985-Reagan.txt :  1
# 1986-Reagan.txt :  1
# 1987-Reagan.txt :  1
# 1988-Reagan.txt :  2
# 1989-Bush.txt :  1
# 1990-Bush.txt :  2
# 1991-Bush-1.txt :  0
# 1991-Bush-2.txt :  0
# 1992-Bush.txt :  3
# 1993-Clinton.txt :  1
# 1994-Clinton.txt :  2
# 1995-Clinton.txt :  1
# 1996-Clinton.txt :  2
# 1997-Clinton.txt :  1
# 1998-Clinton.txt :  4
# 1999-Clinton.txt :  1
# 2000-Clinton.txt :  3
# 2001-GWBush-1.txt :  1
# 2001-GWBush-2.txt :  0
# 2002-GWBush.txt :  0
# 2003-GWBush.txt :  3
# 2004-GWBush.txt :  2
# 2005-GWBush.txt :  2
# 2006-GWBush.txt :  0

# %%
import random
def decode(text):
    random.seed(0)
    # Replace words with 0.1 probability
    return [w if random.random() < 0.9 else gematria(w) for w in text]

# %%
text = state_union.words("1946-Truman.txt")
" ".join([str(w) for w in decode(text)])
# Out:
# 'PRESIDENT HARRY S . TRUMAN \' S MESSAGE TO THE 931 ON THE STATE OF THE 186 55 ON 413 BUDGET FOR 1946 . January 21 , 1946 0 414 January 14 , 1946 To the Congress of the United States : A quarter century ago the Congress decided 809 it could no longer consider 413 financial programs of the various departments 120 a piecemeal basis . Instead it has called on the President to present a comprehensive 500 Budget . 413 Congress has shown its satisfaction with that method 12 extending the budget 1055 55 tightening its controls . The bigger and more complex the Federal Program , the more necessary it is 350 the Chief Executive to submit a single budget 350 action by 413 Congress . At the 346 time , it is clear that the budgetary program and the 294 program of the Government 206 actually inseparable 0 The President bears the responsibility for recommending to the Congress a comprehensive set of proposals on all Government activities and their financing . 60 formulating policies , 301 in preparing budgetary estimates mates , the Nation and the Congress have the right to expect the President to adjust and coordinate the views of the various departments and agencies to form a unified program 0 And that program 826 consideration in connection with the Budget , which is the annual work program 150 the Government . Since our programs for this period which combines war liquidation with reconversion to a peacetime 248 206 524 large and numerous it is 757 that they be planned and executed with the utmost efficiency and the utmost economy 0 We have cut the war program to the maximum extent consistent with national security 0 We have 47 our peacetime programs to the level necessary 470 our national 865 - being and the attainment of our postwar objectives . Where increased programs have 62 recommended , the increases have been held 301 low as is consistent with these 404 . I can assure the Congress 150 413 necessity of these programs . 10 can further assure the Congress that the program 301 a whole is well within our capacity to finance it . All the programs I have recommended for action are included in 413 Budget 604 . For these reasons I 20 chosen 470 combine the customary Message on the State of the Union with the annual Budget Message , and 470 include in the Budget not only estimates for functions authorized by the Congress , but also 350 those which I recommend for its action . I am also transmitting herewith the Fifth Quarterly Report of the Director of War Mobilization and Reconversion 0 1 410 is a comprehensive discussion of the present state of the reconversion program and 150 the 515 55 long - range needs and recommendations . This constitutes , then , as 633 1 report as I find it possible to prepare 920 0 It constitutes a program of government in 766 to the Nation \' s needs 0 With the growing responsibility of modern government to foster 251 expansion 55 to promote conditions 809 812 full and 720 employment opportunities , it 309 become necessary to formulate and determine the Government program in the light of national economic conditions as a whole . 60 both the executive and the legislative branches we 746 make arrangements which will permit us to formulate the Government program 60 that light . Such an approach has become imperative if the American political and economic system is to succeed under the 967 of economic instability and uncertainty which we have to face . 413 Government needs to assure business , labor 0 and agriculture that Government policies will take due account of the requirements of a full employment economy . The lack of that assurance would , I believe , aggravate the economic instability . With the passage of a full employment bill which I confidently anticipate for 413 very near future , the executive and legislative branches of government will be empowered to devote their 707 talents and resources in subsequent years to 629 and acting on such a program . 1The report dated January 1 , 1946 , and entitled " B ...
