# %% [markdown]
# Write code to initialize a two-dimensional array of sets called `word_vowels` and process a list of words, adding each word to `word_vowels[l][v]` where `l` is the length of the word and `v` is the number of vowels it contains.

# %%
def word_vowels(words):
    max_word_length = max(len(w) for w in words)
    matrix = [[set() for _ in range(max_word_length+1)] for _ in range(max_word_length+1)]
    for word in words:
        v = len([c for c in word if c in "aeiou"])
        l = len(word)
        matrix[l][v].add(word)
    return matrix

# %%
words = "La Repubblica, una e indivisibile, riconosce e promuove le autonomie locali; attua nei servizi che dipendono dallo Stato il più ampio decentramento amministrativo; adegua i principi ed i metodi della sua legislazione alle esigenze dell'autonomia e del decentramento."
words = words.split()
word_vowels(words)
# Out:
# [[set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   {'e', 'i'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   {'La', 'ed', 'il', 'le'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   {'che', 'del', 'più'},
#   {'nei', 'sua', 'una'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   {'alle'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   {'Stato', 'dallo', 'della'},
#   {'ampio', 'attua'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   {'metodi'},
#   {'adegua'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   {'locali;', 'servizi'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   {'principi'},
#   {'esigenze', 'promuove'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   set(),
#   {'dipendono', 'riconosce'},
#   set(),
#   {'autonomie'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   set(),
#   {'Repubblica,'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   {'legislazione'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   {'decentramento'},
#   {'indivisibile,'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   {'decentramento.'},
#   set(),
#   {"dell'autonomia"},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   {'amministrativo;'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()]]
