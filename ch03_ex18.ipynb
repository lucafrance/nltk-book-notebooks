# %%
import re
import nltk

# %%
raw_text = open("ch02/corpus.txt", "rt", encoding="utf8").read()[:100000]

# %%
tokens = nltk.word_tokenize(raw_text)

# %%
[w for w in tokens if re.search("^[Ww]h[a-z]+", w)]
# Out:
# ['whatsoever',
#  'where',
#  'who',
#  'which',
#  'which',
#  'who',
#  'what',
#  'what',
#  'which',
#  'which',
#  'which',
#  'where',
#  'while',
#  'who',
#  'Why',
#  'which',
#  'while',
#  'who',
#  'who',
#  'who',
#  'what',
#  'what',
#  'what',
#  'who',
#  'when',
#  'What',
#  'when',
#  'which',
#  'who',
#  'which',
#  'while',
#  'when',
#  'whether',
#  'which',
#  'When',
#  'what',
#  'which',
#  'which',
#  'whole',
#  'who',
#  'which',
#  'who',
#  'which',
#  'whips',
#  'What',
#  'What',
#  'What',
#  'when',
#  'wheels',
#  'whom',
#  'white',
#  'which',
#  'white',
#  'white',
#  'where',
#  'where',
#  'which',
#  'white',
#  'when',
#  'Whatever',
#  'when',
#  'when',
#  'when',
#  'who',
#  'whom',
#  'whom',
#  'whistling',
#  'Where',
#  'whirling',
#  'white',
#  'What',
#  'What',
#  'What',
#  'what',
#  'which',
#  'while',
#  'who',
#  'When',
#  'white',
#  'what',
#  'whichever',
#  'white',
#  'whose',
#  'whom',
#  'whirl',
# ...
